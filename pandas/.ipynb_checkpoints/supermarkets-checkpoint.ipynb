# %%
import os
os.listdir()
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'jupyter_notebook',
#  'lived.csv',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.ipynb',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
import pandas

# %%
df1 = pandas.read_csv('supermarkets.csv')
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_csv('lived.csv')
df2
# Out:
#    ID  Number           Street      Suburb           Shire  Postcode
# 0   1      67       McPhailAve  Kingscliff      TweedShire      2487
# 1   2     541         EvironRd      Eviron      TweedShire      2484
# 2   3       6    GilcrestCourt  Molindinar  GoldCoastShire      4205
# 3   4      23       RespallWay     Arundel  GoldCoastShire      4214
# 4   5      34  DellwoodCircuit  Molendinar  GoldCoastShire      4214

# %%
df3 = pandas.read_json('supermarkets.json')
df3.set_index('ID')
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df4 = pandas.read_excel('supermarkets.xlsx', sheetname=0)
df4.set_index('ID')
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df5 = pandas.read_csv('supermarkets-commas.txt')
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6 = pandas.read_csv('supermarkets-semi-colons.txt', sep=';')
df6
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
pandas.read_csv?

# %%
df2=pandas.read_csv('lived.csv')
df2.set_index('Number', inplace=True)
df2
# Out:
#         ID           Street      Suburb           Shire  Postcode
# Number
# 67       1       McPhailAve  Kingscliff      TweedShire      2487
# 541      2         EvironRd      Eviron      TweedShire      2484
# 6        3    GilcrestCourt  Molindinar  GoldCoastShire      4205
# 23       4       RespallWay     Arundel  GoldCoastShire      4214
# 34       5  DellwoodCircuit  Molendinar  GoldCoastShire      4214

# %%
list(df2.loc[:,'Suburb'])
# Out:
# ['Kingscliff', 'Eviron', 'Molindinar', 'Arundel', 'Molendinar']

# %%
df2.iloc[0:2,1:3]
# Out:
#             Street      Suburb
# Number
# 67      McPhailAve  Kingscliff
# 541       EvironRd      Eviron

# %%
# df2.set_index('Shire', inplace=True)
df2.drop('TweedShire', 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'Shire'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-933ef3618f8c> in <module>()
# ----> 1 df2.set_index('Shire', inplace=True)
#       2 df2.drop('TweedShire', 0)
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2828                 names.append(None)
#    2829             else:
# -> 2830                 level = frame[col]._values
#    2831                 names.append(col)
#    2832                 if drop:
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'Shire'

# %%
import pandas
df8 = pandas.read_csv('lived.csv')
df8.set_index('ID', inplace=True)
df8
# Out:
#     Number           Street      Suburb           Shire  Postcode
# ID
# 1       67       McPhailAve  Kingscliff      TweedShire      2487
# 2      541         EvironRd      Eviron      TweedShire      2484
# 3        6    GilcrestCourt  Molindinar  GoldCoastShire      4205
# 4       23       RespallWay     Arundel  GoldCoastShire      4214
# 5       34  DellwoodCircuit  Molendinar  GoldCoastShire      4214

# %%
df8['Any Good'] = df8.shape[0]*['Not too pretty good']
df8
# Out:
#     Number           Street      Suburb           Shire  Postcode  \
# ID
# 1       67       McPhailAve  Kingscliff      TweedShire      2487
# 2      541         EvironRd      Eviron      TweedShire      2484
# 3        6    GilcrestCourt  Molindinar  GoldCoastShire      4205
# 4       23       RespallWay     Arundel  GoldCoastShire      4214
# 5       34  DellwoodCircuit  Molendinar  GoldCoastShire      4214
#
#                Any Good
# ID
# 1   Not too pretty good
# 2   Not too pretty good
# 3   Not too pretty good
# 4   Not too pretty good
# 5   Not too pretty good

# %%
df8.loc[1,'Any Good'] = 'Nah'
df8
# Out:
#     Number           Street      Suburb           Shire  Postcode  \
# ID
# 1       67       McPhailAve  Kingscliff      TweedShire      2487
# 2      541         EvironRd      Eviron      TweedShire      2484
# 3        6    GilcrestCourt  Molindinar  GoldCoastShire      4205
# 4       23       RespallWay     Arundel  GoldCoastShire      4214
# 5       34  DellwoodCircuit  Molendinar  GoldCoastShire      4214
#
#                Any Good
# ID
# 1                   Nah
# 2   Not too pretty good
# 3   Not too pretty good
# 4   Not too pretty good
# 5   Not too pretty good

# %%
df8.loc[1, 'Any Good'] = 'Yeah man family home'
df8.loc[4, 'Any Good'] = 'Meh'
df8
# Out:
#     Number           Street      Suburb           Shire  Postcode  \
# ID
# 1       67       McPhailAve  Kingscliff      TweedShire      2487
# 2      541         EvironRd      Eviron      TweedShire      2484
# 3        6    GilcrestCourt  Molindinar  GoldCoastShire      4205
# 4       23       RespallWay     Arundel  GoldCoastShire      4214
# 5       34  DellwoodCircuit  Molendinar  GoldCoastShire      4214
#
#                 Any Good
# ID
# 1   Yeah man family home
# 2    Not too pretty good
# 3    Not too pretty good
# 4                    Meh
# 5    Not too pretty good

# %%
df9 = pandas.read_csv('lived.csv')
df9
# Out:
#    ID  Number           Street      Suburb           Shire  Postcode
# 0   1      67       McPhailAve  Kingscliff      TweedShire      2487
# 1   2     541         EvironRd      Eviron      TweedShire      2484
# 2   3       6    GilcrestCourt  Molindinar  GoldCoastShire      4205
# 3   4      23       RespallWay     Arundel  GoldCoastShire      4214
# 4   5      34  DellwoodCircuit  Molendinar  GoldCoastShire      4214

# %%
df9_t = df9.T
df9_t
# Out:
#                    0           1               2               3  \
# ID                 1           2               3               4
# Number            67         541               6              23
# Street    McPhailAve    EvironRd   GilcrestCourt      RespallWay
# Suburb    Kingscliff      Eviron      Molindinar         Arundel
# Shire     TweedShire  TweedShire  GoldCoastShire  GoldCoastShire
# Postcode        2487        2484            4205            4214
#
#                         4
# ID                      5
# Number                 34
# Street    DellwoodCircuit
# Suburb         Molendinar
# Shire      GoldCoastShire
# Postcode             4214

# %%
df9_t[5] = [6, 333, 'Cornwall Street', 'Greenslopes', 'Brisbane', '4105']
df9_t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1175             result = expressions.evaluate(op, str_rep, x, y,
# -> 1176                                           raise_on_error=True, **eval_kwargs)
#    1177         except TypeError:
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, raise_on_error, use_numexpr, **eval_kwargs)
#     210         return _evaluate(op, op_str, a, b, raise_on_error=raise_on_error,
# --> 211                          **eval_kwargs)
#     212     return _evaluate_standard(op, op_str, a, b, raise_on_error=raise_on_error)
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, raise_on_error, truediv, reversed, **eval_kwargs)
#     121     if result is None:
# --> 122         result = _evaluate_standard(op, op_str, a, b, raise_on_error)
#     123
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, raise_on_error, **eval_kwargs)
#      63     with np.errstate(all='ignore'):
# ---> 64         return op(a, b)
#      65
#
# TypeError: must be str, not int
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in eval(self, func, other, raise_on_error, try_cast, mgr)
#    1183             with np.errstate(all='ignore'):
# -> 1184                 result = get_result(other)
#    1185
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get_result(other)
#    1152             else:
# -> 1153                 result = func(values, other)
#    1154
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1201                     with np.errstate(all='ignore'):
# -> 1202                         result[mask] = op(xrav, y)
#    1203             else:
#
# TypeError: must be str, not int
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-7849e45ca775> in <module>()
# ----> 1 df9_t[str(len(df9_t-1))] = [len(df9_t+1), 333, 'Cornwall Street', 'Greenslopes', 'Brisbane', '4105']
#       2 df9_t
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in f(self, other, axis, level, fill_value)
#    1239                 self = self.fillna(fill_value)
#    1240
# -> 1241             return self._combine_const(other, na_op)
#    1242
#    1243     f.__name__ = name
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _combine_const(self, other, func, raise_on_error)
#    3541     def _combine_const(self, other, func, raise_on_error=True):
#    3542         new_data = self._data.eval(func=func, other=other,
# -> 3543                                    raise_on_error=raise_on_error)
#    3544         return self._constructor(new_data)
#    3545
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in eval(self, **kwargs)
#    3195
#    3196     def eval(self, **kwargs):
# -> 3197         return self.apply('eval', **kwargs)
#    3198
#    3199     def quantile(self, **kwargs):
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3089
#    3090             kwargs['mgr'] = self
# -> 3091             applied = getattr(b, f)(**kwargs)
#    3092             result_blocks = _extend_blocks(applied, result_blocks)
#    3093
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in eval(self, func, other, raise_on_error, try_cast, mgr)
#    1189             raise
#    1190         except Exception as detail:
# -> 1191             result = handle_error()
#    1192
#    1193         # technically a broadcast error in numpy can 'work' by returning a
#
# /Users/jacobprichard/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in handle_error()
#    1172                 # The 'detail' variable is defined in outer scope.
#    1173                 raise TypeError('Could not operate %s with block values %s' %
# -> 1174                                 (repr(other), str(detail)))  # noqa
#    1175             else:
#    1176                 # return the values
#
# TypeError: Could not operate 1 with block values must be str, not int
